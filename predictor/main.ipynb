# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
tsla = pd.read_csv("TSLA.csv")
tsla.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-06-16  377.980011  378.010010  370.100006  371.399994  371.399994
# 1  2017-06-19  375.000000  376.700012  367.799988  369.799988  369.799988
# 2  2017-06-20  376.670013  378.880005  369.730011  372.239990  372.239990
# 3  2017-06-21  374.350006  376.989990  368.019989  376.399994  376.399994
# 4  2017-06-22  377.989990  385.000000  373.570007  382.609985  382.609985
#
#     Volume
# 0  6731000
# 1  6549300
# 2  7438700
# 3  4923200
# 4  7529800

# %%
tsla_mean = tsla.groupby('Date').mean()
tsla_mean.head()
# Out:
#                   Open        High         Low       Close   Adj Close
# Date
# 2017-06-16  377.980011  378.010010  370.100006  371.399994  371.399994
# 2017-06-19  375.000000  376.700012  367.799988  369.799988  369.799988
# 2017-06-20  376.670013  378.880005  369.730011  372.239990  372.239990
# 2017-06-21  374.350006  376.989990  368.019989  376.399994  376.399994
# 2017-06-22  377.989990  385.000000  373.570007  382.609985  382.609985

# %%
tsla_mean.plot(figsize=(12, 18))

# %%
maximum_drop_tsla = max(tsla['Open'] - tsla['Low'])
maximum_drop_tsla
# Out:
# 20.870024999999998

# %%
tsla.loc[(tsla['Open'] - tsla['Low']) == maximum_drop_tsla]
# Out:
#           Date        Open       High         Low       Close   Adj Close
# 12  2017-07-05  347.200012  347.23999  326.329987  327.089996  327.089996

# %%
maximum_up_tsla = max(tsla['High'] - tsla['Open'])
maximum_up_tsla
# Out:
# 16.669983000000002

# %%
tsla.loc[(tsla['High'] - tsla['Open'] == maximum_up_tsla)]
# Out:
#            Date        Open        High         Low       Close   Adj Close
# 104  2017-11-13  300.130005  316.799988  299.109985  315.399994  315.399994

# %%
tsla_array = np.array([tsla['Open'], tsla['High'], tsla['Low'], tsla['Close']])
nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(tsla_array)

# %%
distances, indices = nbrs.kneighbors(tsla_array)
indices
distances
# Out:
# array([[  0.        ,  64.88768584],
#        [  0.        ,  64.88768584],
#        [  0.        ,  72.78095271],
#        [  0.        ,  72.78095271]])

# %%
x_train, x_test, y_train, y_test = train_test_split(tsla.data, tsla.target, test_size=0.25, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-72e99a0d2f38> in <module>()
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(tsla.data, tsla.target, test_size=0.25, random_state=0)
#
# NameError: name 'train_test_split' is not defined
